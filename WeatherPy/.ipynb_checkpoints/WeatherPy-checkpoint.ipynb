# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../Output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="
print("Beginning Data Retrieval")
print("__________________________________")

record_count = 1
set_count = 1

for i, city in enumerate (cities):
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count=0
        
    city_url = url + city
    
    print("Processing record %s of set %s | %s" %(record_count, set_count, city))
    record_count+=1
    try:
        city_weather=requests.get(query_url + city).json()
        temperature=city_weather['main']['temp']
        humidity=city_weather['main']['humidity']
        cloudiness=city_weather['clouds']['all']
        wind_speed=city_weather['wind']['speed']
        city_lat=city_weather["coord"]["lat"]
        city_lon=city_weather["coord"]["lon"]
        city_country=city_weather["sys"]["country"]
        city_date=city_weather["dt"]
        city_data.append({"City":city,
                        "Lat":city_lat,
                        "Lng":city_lon,
                        "Max temp": temperature,
                        "Humidity": humidity,
                        "Cloudiness": cloudiness,
                        "Wind_speed": wind_speed,
                        "Country": city_country,
                        "Date" : city_date})
    except:
            print("City not found. Skipping")
            pass
print("-------------------------------------")
print("Data retrival completed")
print("-------------------------------------")
# Out:
# Beginning Data Retrieval
# __________________________________
# Processing record 1 of set 1 | catalao
# Processing record 2 of set 1 | provideniya
# Processing record 3 of set 1 | airai
# Processing record 4 of set 1 | raglan
# Processing record 5 of set 1 | chokurdakh
# Processing record 6 of set 1 | hasaki
# Processing record 7 of set 1 | les escoumins
# Processing record 8 of set 1 | makung
# City not found. Skipping
# Processing record 9 of set 1 | longhua
# Processing record 10 of set 1 | east london
# Processing record 11 of set 1 | rio grande
# Processing record 12 of set 1 | castro
# Processing record 13 of set 1 | rikitea
# Processing record 14 of set 1 | sebezh
# Processing record 15 of set 1 | jamestown
# Processing record 16 of set 1 | busselton
# Processing record 17 of set 1 | cape town
# Processing record 18 of set 1 | barrow
# Processing record 19 of set 1 | hobart
# Processing record 20 of set 1 | birjand
# Processing record 21 of set 1 | tuktoyaktuk
# Processing record 22 of set 1 | esfarayen
# Processing record 23 of set 1 | vaini
# Processing record 24 of set 1 | komsomolskiy
# Processing record 25 of set 1 | adrar
# Processing record 26 of set 1 | punta arenas
# Processing record 27 of set 1 | ostrovnoy
# Processing record 28 of set 1 | concepcion del oro
# Processing record 29 of set 1 | kodiak
# Processing record 30 of set 1 | teya
# Processing record 31 of set 1 | buchanan
# Processing record 32 of set 1 | kalispell
# Processing record 33 of set 1 | waipawa
# Processing record 34 of set 1 | torbay
# Processing record 35 of set 1 | vao
# Processing record 36 of set 1 | bam
# Processing record 37 of set 1 | hermanus
# Processing record 38 of set 1 | bose
# Processing record 39 of set 1 | saint-joseph
# Processing record 40 of set 1 | krasnoyarsk-45
# City not found. Skipping
# Processing record 41 of set 1 | taolanaro
# City not found. Skipping
# Processing record 42 of set 1 | togur
# Processing record 43 of set 1 | thompson
# Processing record 44 of set 1 | ushuaia
# Processing record 45 of set 1 | cherskiy
# Processing record 46 of set 1 | kahului
# Processing record 47 of set 1 | katsuura
# Processing record 48 of set 1 | cayenne
# Processing record 49 of set 1 | mys shmidta
# City not found. Skipping
# Processing record 50 of set 1 | ribeira grande
# Processing record 0 of set 2 | grand river south east
# City not found. Skipping
# Processing record 1 of set 2 | salalah
# Processing record 2 of set 2 | ilulissat
# Processing record 3 of set 2 | bluff
# Processing record 4 of set 2 | hualmay
# Processing record 5 of set 2 | orlik
# Processing record 6 of set 2 | ancud
# Processing record 7 of set 2 | severnoye
# Processing record 8 of set 2 | batagay-alyta
# Processing record 9 of set 2 | talnakh
# Processing record 10 of set 2 | saskylakh
# Processing record 11 of set 2 | lamar
# Processing record 12 of set 2 | ninghai
# Processing record 13 of set 2 | simao
# Processing record 14 of set 2 | kampene
# Processing record 15 of set 2 | natal
# Processing record 16 of set 2 | mount gambier
# Processing record 17 of set 2 | pisco
# Processing record 18 of set 2 | new norfolk
# Processing record 19 of set 2 | miyang
# Processing record 20 of set 2 | bathsheba
# Processing record 21 of set 2 | qaanaaq
# Processing record 22 of set 2 | nikolskoye
# Processing record 23 of set 2 | lavrentiya
# Processing record 24 of set 2 | conde
# Processing record 25 of set 2 | hithadhoo
# Processing record 26 of set 2 | novo aripuana
# Processing record 27 of set 2 | vestmannaeyjar
# Processing record 28 of set 2 | nara
# Processing record 29 of set 2 | houma
# Processing record 30 of set 2 | barentsburg
# City not found. Skipping
# Processing record 31 of set 2 | ormara
# Processing record 32 of set 2 | belushya guba
# City not found. Skipping
# Processing record 33 of set 2 | tchibanga
# Processing record 34 of set 2 | harper
# Processing record 35 of set 2 | limoeiro do norte
# Processing record 36 of set 2 | port alfred
# Processing record 37 of set 2 | shahjahanpur
# Processing record 38 of set 2 | lerwick
# Processing record 39 of set 2 | port lincoln
# Processing record 40 of set 2 | luderitz
# Processing record 41 of set 2 | lebu
# Processing record 42 of set 2 | pawayan
# Processing record 43 of set 2 | mataura
# Processing record 44 of set 2 | yellowknife
# Processing record 45 of set 2 | bredasdorp
# Processing record 46 of set 2 | chuy
# Processing record 47 of set 2 | hilo
# Processing record 48 of set 2 | ixtapa
# Processing record 49 of set 2 | toktogul
# Processing record 0 of set 3 | bangalore
# Processing record 1 of set 3 | san patricio
# Processing record 2 of set 3 | nanortalik
# Processing record 3 of set 3 | rexburg
# Processing record 4 of set 3 | constantine
# Processing record 5 of set 3 | butaritari
# Processing record 6 of set 3 | saldanha
# Processing record 7 of set 3 | raga
# Processing record 8 of set 3 | louisbourg
# City not found. Skipping
# Processing record 9 of set 3 | cap malheureux
# Processing record 10 of set 3 | mazagao
# Processing record 11 of set 3 | avarua
# Processing record 12 of set 3 | guerrero negro
# Processing record 13 of set 3 | avera
# Processing record 14 of set 3 | las margaritas
# Processing record 15 of set 3 | lexington
# Processing record 16 of set 3 | dikson
# Processing record 17 of set 3 | half moon bay
# Processing record 18 of set 3 | esperance
# Processing record 19 of set 3 | geraldton
# Processing record 20 of set 3 | tharad
# Processing record 21 of set 3 | broome
# Processing record 22 of set 3 | awbari
# Processing record 23 of set 3 | bambous virieux
# Processing record 24 of set 3 | rawson
# Processing record 25 of set 3 | ngukurr
# City not found. Skipping
# Processing record 26 of set 3 | kungurtug
# Processing record 27 of set 3 | port elizabeth
# Processing record 28 of set 3 | albany
# Processing record 29 of set 3 | aksarka
# Processing record 30 of set 3 | praya
# Processing record 31 of set 3 | flinders
# Processing record 32 of set 3 | mahina
# Processing record 33 of set 3 | oktyabrskoye
# Processing record 34 of set 3 | souillac
# Processing record 35 of set 3 | samusu
# City not found. Skipping
# Processing record 36 of set 3 | shimoda
# Processing record 37 of set 3 | vaitupu
# City not found. Skipping
# Processing record 38 of set 3 | praia
# Processing record 39 of set 3 | khatanga
# Processing record 40 of set 3 | hirara
# Processing record 41 of set 3 | bundaberg
# Processing record 42 of set 3 | narsaq
# Processing record 43 of set 3 | mar del plata
# Processing record 44 of set 3 | gboko
# Processing record 45 of set 3 | arraial do cabo
# Processing record 46 of set 3 | boulsa
# Processing record 47 of set 3 | nome
# Processing record 48 of set 3 | san quintin
# Processing record 49 of set 3 | lolua
# City not found. Skipping
# Processing record 0 of set 4 | huarmey
# Processing record 1 of set 4 | hami
# Processing record 2 of set 4 | palabuhanratu
# City not found. Skipping
# Processing record 3 of set 4 | bethel
# Processing record 4 of set 4 | lake havasu city
# Processing record 5 of set 4 | buluang
# Processing record 6 of set 4 | beringovskiy
# Processing record 7 of set 4 | puerto ayora
# Processing record 8 of set 4 | karkaralinsk
# City not found. Skipping
# Processing record 9 of set 4 | georgetown
# Processing record 10 of set 4 | quatre cocos
# Processing record 11 of set 4 | sorland
# Processing record 12 of set 4 | acari
# Processing record 13 of set 4 | bikapur
# Processing record 14 of set 4 | haibowan
# City not found. Skipping
# Processing record 15 of set 4 | goderich
# Processing record 16 of set 4 | norman wells
# Processing record 17 of set 4 | ponta do sol
# Processing record 18 of set 4 | champerico
# Processing record 19 of set 4 | waycross
# Processing record 20 of set 4 | canoinhas
# Processing record 21 of set 4 | ossora
# Processing record 22 of set 4 | thinadhoo
# Processing record 23 of set 4 | salamiyah
# Processing record 24 of set 4 | vanavara
# Processing record 25 of set 4 | mitu
# Processing record 26 of set 4 | guia de isora
# Processing record 27 of set 4 | along
# Processing record 28 of set 4 | atuona
# Processing record 29 of set 4 | port hardy
# Processing record 30 of set 4 | evansville
# Processing record 31 of set 4 | pokrovskoye
# Processing record 32 of set 4 | iqaluit
# Processing record 33 of set 4 | gelemso
# Processing record 34 of set 4 | saint-philippe
# Processing record 35 of set 4 | coihaique
# Processing record 36 of set 4 | ribeirao branco
# Processing record 37 of set 4 | hervey bay
# Processing record 38 of set 4 | kudat
# Processing record 39 of set 4 | sidi ali
# Processing record 40 of set 4 | luanda
# Processing record 41 of set 4 | bobo dioulasso
# Processing record 42 of set 4 | amderma
# City not found. Skipping
# Processing record 43 of set 4 | sisimiut
# Processing record 44 of set 4 | maloshuyka
# City not found. Skipping
# Processing record 45 of set 4 | mayya
# Processing record 46 of set 4 | tiksi
# Processing record 47 of set 4 | aklavik
# Processing record 48 of set 4 | carnarvon
# Processing record 49 of set 4 | tual
# Processing record 0 of set 5 | saint marys
# Processing record 1 of set 5 | lac du bonnet
# Processing record 2 of set 5 | kununurra
# Processing record 3 of set 5 | languyan
# Processing record 4 of set 5 | salinas
# Processing record 5 of set 5 | jertih
# Processing record 6 of set 5 | lagoa
# Processing record 7 of set 5 | eldikan
# City not found. Skipping
# Processing record 8 of set 5 | mujiayingzi
# Processing record 9 of set 5 | sao joao da barra
# Processing record 10 of set 5 | sagua la grande
# Processing record 11 of set 5 | carutapera
# Processing record 12 of set 5 | susurluk
# Processing record 13 of set 5 | sola
# Processing record 14 of set 5 | topalu
# Processing record 15 of set 5 | tuatapere
# Processing record 16 of set 5 | guangyuan
# Processing record 17 of set 5 | tawkar
# City not found. Skipping
# Processing record 18 of set 5 | magistralnyy
# Processing record 19 of set 5 | illoqqortoormiut
# City not found. Skipping
# Processing record 20 of set 5 | sarahan
# Processing record 21 of set 5 | coromandel
# Processing record 22 of set 5 | padang
# Processing record 23 of set 5 | upernavik
# Processing record 24 of set 5 | ovruch
# Processing record 25 of set 5 | constitucion
# Processing record 26 of set 5 | roald
# Processing record 27 of set 5 | yulara
# Processing record 28 of set 5 | kanash
# Processing record 29 of set 5 | marienburg
# Processing record 30 of set 5 | esik
# Processing record 31 of set 5 | cabo san lucas
# Processing record 32 of set 5 | asau
# Processing record 33 of set 5 | seoul
# Processing record 34 of set 5 | studenka
# Processing record 35 of set 5 | aksha
# Processing record 36 of set 5 | olovyannaya
# Processing record 37 of set 5 | nebolchi
# Processing record 38 of set 5 | namatanai
# Processing record 39 of set 5 | olafsvik
# Processing record 40 of set 5 | vitim
# Processing record 41 of set 5 | zhigansk
# Processing record 42 of set 5 | lons-le-saunier
# Processing record 43 of set 5 | saint george
# Processing record 44 of set 5 | boden
# Processing record 45 of set 5 | longyearbyen
# Processing record 46 of set 5 | kismayo
# Processing record 47 of set 5 | nantucket
# Processing record 48 of set 5 | kapaa
# Processing record 49 of set 5 | faanui
# Processing record 0 of set 6 | coquimbo
# Processing record 1 of set 6 | marcona
# City not found. Skipping
# Processing record 2 of set 6 | sitka
# Processing record 3 of set 6 | belyy yar
# Processing record 4 of set 6 | dunedin
# Processing record 5 of set 6 | mae sai
# Processing record 6 of set 6 | turbat
# Processing record 7 of set 6 | athmallik
# Processing record 8 of set 6 | marau
# Processing record 9 of set 6 | ulkan
# Processing record 10 of set 6 | lahij
# Processing record 11 of set 6 | emerald
# Processing record 12 of set 6 | bonthe
# Processing record 13 of set 6 | phan rang
# City not found. Skipping
# Processing record 14 of set 6 | kaitangata
# Processing record 15 of set 6 | bolungarvik
# City not found. Skipping
# Processing record 16 of set 6 | saint anthony
# Processing record 17 of set 6 | contramaestre
# Processing record 18 of set 6 | victoria
# Processing record 19 of set 6 | bargal
# City not found. Skipping
# Processing record 20 of set 6 | batemans bay
# Processing record 21 of set 6 | severo-kurilsk
# Processing record 22 of set 6 | devils lake
# Processing record 23 of set 6 | yanam
# Processing record 24 of set 6 | sumbawa
# City not found. Skipping
# Processing record 25 of set 6 | nuuk
# Processing record 26 of set 6 | north bend
# Processing record 27 of set 6 | kaabong
# Processing record 28 of set 6 | voznesenye
# Processing record 29 of set 6 | coahuayana
# Processing record 30 of set 6 | darnah
# Processing record 31 of set 6 | high prairie
# Processing record 32 of set 6 | guanare
# Processing record 33 of set 6 | ambunti
# Processing record 34 of set 6 | bandarbeyla
# Processing record 35 of set 6 | sinnamary
# Processing record 36 of set 6 | ascope
# Processing record 37 of set 6 | cidreira
# Processing record 38 of set 6 | riacho de santana
# Processing record 39 of set 6 | raudeberg
# Processing record 40 of set 6 | xuddur
# Processing record 41 of set 6 | keila
# Processing record 42 of set 6 | bengkulu
# Processing record 43 of set 6 | tsihombe
# City not found. Skipping
# Processing record 44 of set 6 | altay
# Processing record 45 of set 6 | robertsport
# Processing record 46 of set 6 | pangai
# Processing record 47 of set 6 | vardo
# Processing record 48 of set 6 | san jose
# Processing record 49 of set 6 | jarjis
# City not found. Skipping
# Processing record 0 of set 7 | wenling
# Processing record 1 of set 7 | paamiut
# Processing record 2 of set 7 | abu samrah
# Processing record 3 of set 7 | santarem
# Processing record 4 of set 7 | aswan
# Processing record 5 of set 7 | malakal
# Processing record 6 of set 7 | melfort
# Processing record 7 of set 7 | vila franca do campo
# Processing record 8 of set 7 | muros
# Processing record 9 of set 7 | bilibino
# Processing record 10 of set 7 | carballo
# Processing record 11 of set 7 | nguru
# Processing record 12 of set 7 | atambua
# Processing record 13 of set 7 | brae
# Processing record 14 of set 7 | pevek
# Processing record 15 of set 7 | sao filipe
# Processing record 16 of set 7 | portland
# Processing record 17 of set 7 | kawalu
# Processing record 18 of set 7 | harindanga
# Processing record 19 of set 7 | nanuque
# Processing record 20 of set 7 | yeppoon
# Processing record 21 of set 7 | ankazoabo
# Processing record 22 of set 7 | sosnovo-ozerskoye
# Processing record 23 of set 7 | ostersund
# Processing record 24 of set 7 | north platte
# Processing record 25 of set 7 | bogatyr
# Processing record 26 of set 7 | kamenskoye
# City not found. Skipping
# Processing record 27 of set 7 | estevan
# Processing record 28 of set 7 | freeport
# Processing record 29 of set 7 | kirakira
# Processing record 30 of set 7 | dakar
# Processing record 31 of set 7 | minab
# Processing record 32 of set 7 | scarborough
# Processing record 33 of set 7 | longonjo
# Processing record 34 of set 7 | cancuc
# Processing record 35 of set 7 | vestbygda
# City not found. Skipping
# Processing record 36 of set 7 | solovetskiy
# City not found. Skipping
# Processing record 37 of set 7 | farim
# Processing record 38 of set 7 | koppang
# Processing record 39 of set 7 | codrington
# Processing record 40 of set 7 | pringsewu
# Processing record 41 of set 7 | port washington
# Processing record 42 of set 7 | nizhneyansk
# City not found. Skipping
# Processing record 43 of set 7 | grand gaube
# Processing record 44 of set 7 | porto novo
# Processing record 45 of set 7 | tres arroyos
# Processing record 46 of set 7 | hamilton
# Processing record 47 of set 7 | yvetot
# Processing record 48 of set 7 | muborak
# Processing record 49 of set 7 | paralimni
# Processing record 0 of set 8 | store heddinge
# Processing record 1 of set 8 | nouadhibou
# Processing record 2 of set 8 | starkville
# Processing record 3 of set 8 | kavaratti
# Processing record 4 of set 8 | payakumbuh
# Processing record 5 of set 8 | kalanguy
# Processing record 6 of set 8 | saleaula
# City not found. Skipping
# Processing record 7 of set 8 | tasiilaq
# Processing record 8 of set 8 | bosaso
# Processing record 9 of set 8 | wad madani
# Processing record 10 of set 8 | ahipara
# Processing record 11 of set 8 | tuscaloosa
# Processing record 12 of set 8 | sao geraldo do araguaia
# Processing record 13 of set 8 | korla
# Processing record 14 of set 8 | brownsville
# Processing record 15 of set 8 | babanusah
# City not found. Skipping
# Processing record 16 of set 8 | atbasar
# Processing record 17 of set 8 | alofi
# Processing record 18 of set 8 | reading
# Processing record 19 of set 8 | manokwari
# Processing record 20 of set 8 | la romana
# Processing record 21 of set 8 | sennoy
# Processing record 22 of set 8 | muroto
# Processing record 23 of set 8 | burica
# City not found. Skipping
# Processing record 24 of set 8 | kugesi
# Processing record 25 of set 8 | amurzet
# Processing record 26 of set 8 | miri
# Processing record 27 of set 8 | tomiya
# Processing record 28 of set 8 | salo
# Processing record 29 of set 8 | muyezerskiy
# Processing record 30 of set 8 | kutum
# Processing record 31 of set 8 | rungata
# City not found. Skipping
# Processing record 32 of set 8 | vryburg
# Processing record 33 of set 8 | tondano
# Processing record 34 of set 8 | raver
# Processing record 35 of set 8 | jaltenango
# Processing record 36 of set 8 | vilyuysk
# Processing record 37 of set 8 | saint-augustin
# Processing record 38 of set 8 | saint-paul
# Processing record 39 of set 8 | acarau
# Processing record 40 of set 8 | lompoc
# Processing record 41 of set 8 | kochki
# Processing record 42 of set 8 | hofn
# Processing record 43 of set 8 | ambilobe
# Processing record 44 of set 8 | nova olinda do norte
# Processing record 45 of set 8 | moussoro
# Processing record 46 of set 8 | beckley
# Processing record 47 of set 8 | jackson
# Processing record 48 of set 8 | whitianga
# Processing record 49 of set 8 | lugazi
# Processing record 0 of set 9 | cabedelo
# Processing record 1 of set 9 | ingham
# Processing record 2 of set 9 | chichli
# Processing record 3 of set 9 | nalut
# Processing record 4 of set 9 | porto walter
# Processing record 5 of set 9 | karpathos
# Processing record 6 of set 9 | kurilsk
# Processing record 7 of set 9 | mecca
# Processing record 8 of set 9 | vestmanna
# Processing record 9 of set 9 | broken hill
# Processing record 10 of set 9 | te anau
# Processing record 11 of set 9 | blackwater
# Processing record 12 of set 9 | leh
# Processing record 13 of set 9 | kushmurun
# Processing record 14 of set 9 | sechura
# Processing record 15 of set 9 | la ronge
# Processing record 16 of set 9 | nizhnyaya omka
# Processing record 17 of set 9 | pacific grove
# Processing record 18 of set 9 | bat khela
# Processing record 19 of set 9 | vanimo
# Processing record 20 of set 9 | zhicheng
# Processing record 21 of set 9 | egvekinot
# Processing record 22 of set 9 | namibe
# Processing record 23 of set 9 | ondorhaan
# City not found. Skipping
# Processing record 24 of set 9 | baykit
# Processing record 25 of set 9 | shieli
# Processing record 26 of set 9 | kokopo
# Processing record 27 of set 9 | awjilah
# Processing record 28 of set 9 | krasnoslobodsk
# Processing record 29 of set 9 | inuvik
# Processing record 30 of set 9 | camalu
# Processing record 31 of set 9 | douglas
# Processing record 32 of set 9 | kruisfontein
# Processing record 33 of set 9 | verkhovazhye
# Processing record 34 of set 9 | atsiki
# City not found. Skipping
# Processing record 35 of set 9 | ketchikan
# Processing record 36 of set 9 | chagda
# City not found. Skipping
# Processing record 37 of set 9 | manger
# Processing record 38 of set 9 | matay
# Processing record 39 of set 9 | mahebourg
# Processing record 40 of set 9 | kavieng
# Processing record 41 of set 9 | xining
# Processing record 42 of set 9 | leua
# Processing record 43 of set 9 | san lorenzo
# Processing record 44 of set 9 | marrakesh
# Processing record 45 of set 9 | gigmoto
# Processing record 46 of set 9 | bambanglipuro
# Processing record 47 of set 9 | cordoba
# Processing record 48 of set 9 | kalmunai
# Processing record 49 of set 9 | bourail
# Processing record 0 of set 10 | fortuna
# Processing record 1 of set 10 | mahanje
# Processing record 2 of set 10 | eyl
# Processing record 3 of set 10 | tessalit
# Processing record 4 of set 10 | nhulunbuy
# Processing record 5 of set 10 | oistins
# Processing record 6 of set 10 | clyde river
# Processing record 7 of set 10 | poum
# Processing record 8 of set 10 | vostok
# Processing record 9 of set 10 | lorengau
# Processing record 10 of set 10 | touros
# Processing record 11 of set 10 | leshukonskoye
# Processing record 12 of set 10 | huilong
# Processing record 13 of set 10 | manyana
# Processing record 14 of set 10 | pascagoula
# Processing record 15 of set 10 | mehamn
# Processing record 16 of set 10 | quartucciu
# Processing record 17 of set 10 | gotsu
# Processing record 18 of set 10 | kesinga
# Processing record 19 of set 10 | marystown
# Processing record 20 of set 10 | sangar
# Processing record 21 of set 10 | taunggyi
# Processing record 22 of set 10 | nsanje
# Processing record 23 of set 10 | nyurba
# Processing record 24 of set 10 | mishkino
# Processing record 25 of set 10 | guajara-mirim
# City not found. Skipping
# Processing record 26 of set 10 | mabaruma
# Processing record 27 of set 10 | baruun-urt
# Processing record 28 of set 10 | cairns
# Processing record 29 of set 10 | afyonkarahisar
# Processing record 30 of set 10 | kannangad
# Processing record 31 of set 10 | ca mau
# Processing record 32 of set 10 | athabasca
# Processing record 33 of set 10 | pampa
# Processing record 34 of set 10 | hailey
# Processing record 35 of set 10 | port maria
# Processing record 36 of set 10 | macas
# Processing record 37 of set 10 | promyshlennyy
# Processing record 38 of set 10 | dalvik
# Processing record 39 of set 10 | los llanos de aridane
# Processing record 40 of set 10 | amilpas
# City not found. Skipping
# Processing record 41 of set 10 | ankang
# Processing record 42 of set 10 | iskateley
# Processing record 43 of set 10 | kedrovyy
# Processing record 44 of set 10 | hay river
# Processing record 45 of set 10 | san rafael
# Processing record 46 of set 10 | dreux
# Processing record 47 of set 10 | praia da vitoria
# Processing record 48 of set 10 | gimli
# Processing record 49 of set 10 | porto san giorgio
# Processing record 0 of set 11 | alice springs
# Processing record 1 of set 11 | shumskiy
# Processing record 2 of set 11 | tocopilla
# Processing record 3 of set 11 | fairbanks
# Processing record 4 of set 11 | uzunovo
# Processing record 5 of set 11 | takoradi
# Processing record 6 of set 11 | poso
# Processing record 7 of set 11 | vila velha
# Processing record 8 of set 11 | leningradskiy
# Processing record 9 of set 11 | asmara
# Processing record 10 of set 11 | tabuk
# Processing record 11 of set 11 | cockburn town
# Processing record 12 of set 11 | mundo nuevo
# Processing record 13 of set 11 | killybegs
# Processing record 14 of set 11 | malanje
# Processing record 15 of set 11 | grindavik
# Processing record 16 of set 11 | san cristobal
# Processing record 17 of set 11 | plettenberg bay
# Processing record 18 of set 11 | shuyskoye
# Processing record 19 of set 11 | yinchuan
# Processing record 20 of set 11 | okhotsk
# Processing record 21 of set 11 | khandyga
# Processing record 22 of set 11 | katherine
# Processing record 23 of set 11 | hire
# City not found. Skipping
# Processing record 24 of set 11 | martinsburg
# Processing record 25 of set 11 | springdale
# Processing record 26 of set 11 | irituia
# Processing record 27 of set 11 | jambi
# Processing record 28 of set 11 | ibra
# Processing record 29 of set 11 | pareora
# Processing record 30 of set 11 | kilakarai
# Processing record 31 of set 11 | paysandu
# Processing record 32 of set 11 | tautira
# Processing record 33 of set 11 | morondava
# Processing record 34 of set 11 | rawlins
# Processing record 35 of set 11 | bajil
# Processing record 36 of set 11 | bhawanigarh
# Processing record 37 of set 11 | khoy
# Processing record 38 of set 11 | vogar
# Processing record 39 of set 11 | sungai siput utara
# City not found. Skipping
# Processing record 40 of set 11 | capandanan
# Processing record 41 of set 11 | waingapu
# Processing record 42 of set 11 | rocha
# Processing record 43 of set 11 | kawhia
# Processing record 44 of set 11 | kudahuvadhoo
# Processing record 45 of set 11 | trat
# Processing record 46 of set 11 | lasa
# Processing record 47 of set 11 | fontem
# Processing record 48 of set 11 | ozark
# Processing record 49 of set 11 | carlsbad
# Processing record 0 of set 12 | sentyabrskiy
# City not found. Skipping
# Processing record 1 of set 12 | gwadar
# Processing record 2 of set 12 | garmsar
# Processing record 3 of set 12 | lima
# Processing record 4 of set 12 | kuryk
# Processing record 5 of set 12 | sur
# Processing record 6 of set 12 | mahibadhoo
# Processing record 7 of set 12 | morgan city
# Processing record 8 of set 12 | zwedru
# Processing record 9 of set 12 | samarai
# Processing record 10 of set 12 | duyun
# Processing record 11 of set 12 | vredendal
# Processing record 12 of set 12 | darhan
# Processing record 13 of set 12 | kolokani
# Processing record 14 of set 12 | meyungs
# City not found. Skipping
# Processing record 15 of set 12 | klaksvik
# Processing record 16 of set 12 | sussex
# Processing record 17 of set 12 | upington
# Processing record 18 of set 12 | vaitape
# Processing record 19 of set 12 | nemuro
# Processing record 20 of set 12 | tabou
# Processing record 21 of set 12 | khagrachari
# City not found. Skipping
# Processing record 22 of set 12 | vysokopillya
# Processing record 23 of set 12 | comodoro rivadavia
# Processing record 24 of set 12 | gat
# Processing record 25 of set 12 | the pas
# Processing record 26 of set 12 | pervomayskoye
# Processing record 27 of set 12 | ukiah
# Processing record 28 of set 12 | pandan
# Processing record 29 of set 12 | mosquera
# Processing record 30 of set 12 | arman
# Processing record 31 of set 12 | chiltepec
# Processing record 32 of set 12 | sioux lookout
# Processing record 33 of set 12 | athens
# Processing record 34 of set 12 | waw
# Processing record 35 of set 12 | chumikan
# Processing record 36 of set 12 | eatonton
# Processing record 37 of set 12 | trairi
# Processing record 38 of set 12 | hun
# Processing record 39 of set 12 | tarbagatay
# Processing record 40 of set 12 | manali
# Processing record 41 of set 12 | formosa
# Processing record 42 of set 12 | praxedis guerrero
# Processing record 43 of set 12 | bay city
# Processing record 44 of set 12 | khvorostyanka
# Processing record 45 of set 12 | road town
# Processing record 46 of set 12 | khowst
# Processing record 47 of set 12 | botou
# Processing record 48 of set 12 | ciudad bolivar
# Processing record 49 of set 12 | hobyo
# Processing record 0 of set 13 | bandar-e lengeh
# Processing record 1 of set 13 | srikakulam
# Processing record 2 of set 13 | guacara
# Processing record 3 of set 13 | taoudenni
# Processing record 4 of set 13 | caucaia
# Processing record 5 of set 13 | itoman
# Processing record 6 of set 13 | lazaro cardenas
# Processing record 7 of set 13 | richards bay
# Processing record 8 of set 13 | oranjemund
# Processing record 9 of set 13 | mizoch
# Processing record 10 of set 13 | labrea
# Processing record 11 of set 13 | izhmorskiy
# Processing record 12 of set 13 | waitati
# Processing record 13 of set 13 | sunbury
# Processing record 14 of set 13 | yumen
# Processing record 15 of set 13 | kralendijk
# Processing record 16 of set 13 | solnechnyy
# Processing record 17 of set 13 | kichera
# Processing record 18 of set 13 | marawi
# Processing record 19 of set 13 | severnyy
# Processing record 20 of set 13 | tabiauea
# City not found. Skipping
# Processing record 21 of set 13 | tura
# Processing record 22 of set 13 | ulaanbaatar
# Processing record 23 of set 13 | college
# Processing record 24 of set 13 | warrnambool
# Processing record 25 of set 13 | otane
# Processing record 26 of set 13 | tabas
# Processing record 27 of set 13 | torrelavega
# Processing record 28 of set 13 | amparai
# City not found. Skipping
# -------------------------------------
# Data retrival completed
# -------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_df=pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City    Lat     Lng  Max temp  Humidity  Cloudiness  Wind_speed  \
# 0       matay  28.42   30.78     15.34        51          19        3.84
# 1     ushuaia -54.80  -68.30     13.00        82          90        3.35
# 2   mahebourg -20.41   57.70     25.00        78          40        5.70
# 3  nouadhibou  20.93  -17.03     25.00        33           0        7.70
# 4       bluff -46.60  168.33     12.78        97          99        2.24
#
#   Country        Date
# 0      EG  1609519501
# 1      AR  1609519501
# 2      MU  1609519501
# 3      MR  1609519203
# 4      NZ  1609519501

# %%
city_data_df=city_data_df.drop_duplicates(['City'] , keep ='first') 
city_data_df
# Out:
#              City    Lat     Lng  Max temp  Humidity  Cloudiness  Wind_speed  \
# 0           matay  28.42   30.78     15.34        51          19        3.84
# 1         ushuaia -54.80  -68.30     13.00        82          90        3.35
# 2       mahebourg -20.41   57.70     25.00        78          40        5.70
# 3      nouadhibou  20.93  -17.03     25.00        33           0        7.70
# 4           bluff -46.60  168.33     12.78        97          99        2.24
# ...           ...    ...     ...       ...       ...         ...         ...
# 1139  ulaanbaatar  47.91  106.88    -22.00        67           0        2.24
# 1141  warrnambool -38.38  142.48     60.48        90         100        7.09
# 1142        otane -39.88  176.63     71.01        66          91        2.04
# 1143        tabas  33.60   56.92     35.60        37           0        2.24
# 1144  torrelavega  43.35   -4.05     45.23        61          93        8.99
#
#      Country        Date
# 0         EG  1609519501
# 1         AR  1609519501
# 2         MU  1609519501
# 3         MR  1609519203
# 4         NZ  1609519501
# ...      ...         ...
# 1139      MN  1609532400
# 1141      AU  1609532685
# 1142      NZ  1609532685
# 1143      IR  1609532685
# 1144      ES  1609532686
#
# [930 rows x 9 columns]

# %%
city_data_df.describe()
# Out:
#               Lat         Lng    Max temp    Humidity  Cloudiness  Wind_speed  \
# count  930.000000  930.000000  930.000000  930.000000  930.000000  930.000000
# mean    20.922075   19.458333   25.751989   72.803226   54.193548    5.010462
# std     31.234484   87.091133   30.464340   20.833054   39.655149    4.003041
# min    -54.800000 -179.170000  -50.800000   10.000000    0.000000    0.250000
# 25%     -3.137500  -55.117500    4.270000   62.000000    4.000000    2.132500
# 50%     25.285000   24.740000   24.965000   78.000000   64.000000    4.000000
# 75%     47.572500   93.275000   39.002500   87.000000   91.000000    6.930000
# max     78.220000  179.320000   93.200000  100.000000  100.000000   27.200000
#
#                Date
# count  9.300000e+02
# mean   1.609525e+09
# std    6.429163e+03
# min    1.609519e+09
# 25%    1.609520e+09
# 50%    1.609520e+09
# 75%    1.609533e+09
# max    1.609533e+09

# %%
city_data_df.shape
# Out:
# (930, 9)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
dirty_city_data=city_data_df[(city_data_df["Humidity"] > 100)].index
dirty_city_data
# Out:
# Int64Index([], dtype='int64')

# %%
clean_city_data=city_data_df.drop(dirty_city_data, inplace=False)
clean_city_data=city_data_df.rename(columns={"Max temp":"Max Temp", "Wind_speed":"Wind Speed"})
clean_city_data.head()
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       matay  28.42   30.78     15.34        51          19        3.84
# 1     ushuaia -54.80  -68.30     13.00        82          90        3.35
# 2   mahebourg -20.41   57.70     25.00        78          40        5.70
# 3  nouadhibou  20.93  -17.03     25.00        33           0        7.70
# 4       bluff -46.60  168.33     12.78        97          99        2.24
#
#   Country        Date
# 0      EG  1609519501
# 1      AR  1609519501
# 2      MU  1609519501
# 3      MR  1609519203
# 4      NZ  1609519501

# %%
clean_city_data.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_label=clean_city_data['Lat']
plt.scatter(x_label,clean_city_data['Max Temp'], edgecolors='k')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('City Latitude vs Max Temperature 01/01/21')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(x_label,clean_city_data['Humidity'], edgecolors='k')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs Humidity 01/01/21')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(x_label,clean_city_data['Cloudiness'], edgecolors='k')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs Cloudiness 01/01/21')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(x_label,clean_city_data['Wind Speed'], edgecolors='k')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('City Latitude vs Wind Speed 01/01/21')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values, y_values, edgecolors='k')
    plt.plot(x_values,regress_values, "r-")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
northern_hemisphere_data = clean_city_data.drop(clean_city_data["Lat"].loc[
    (clean_city_data["Lat"] <= 0)].index)
northern_hemisphere_data
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0           matay  28.42   30.78     15.34        51          19        3.84
# 3      nouadhibou  20.93  -17.03     25.00        33           0        7.70
# 6           yumen  40.28   97.20     -9.46        74         100        3.44
# 8      chokurdakh  70.63  147.92    -34.80        86          59        1.71
# 10         nemuro  43.32  145.57     -9.46        83           0        8.04
# ...           ...    ...     ...       ...       ...         ...         ...
# 1137     severnyy  50.68   36.55     32.00        99          90        8.95
# 1138         tura  25.52   90.22     57.06        74          76        3.40
# 1139  ulaanbaatar  47.91  106.88    -22.00        67           0        2.24
# 1143        tabas  33.60   56.92     35.60        37           0        2.24
# 1144  torrelavega  43.35   -4.05     45.23        61          93        8.99
#
#      Country        Date
# 0         EG  1609519501
# 3         MR  1609519203
# 6         CN  1609519502
# 8         RU  1609519504
# 10        JP  1609519394
# ...      ...         ...
# 1137      RU  1609532685
# 1138      IN  1609532685
# 1139      MN  1609532400
# 1143      IR  1609532685
# 1144      ES  1609532686
#
# [661 rows x 9 columns]

# %%
southern_hemisphere_data = clean_city_data.drop(clean_city_data["Lat"].loc[
    (clean_city_data["Lat"] > 0)].index)
southern_hemisphere_data
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 1         ushuaia -54.80  -68.30     13.00        82          90        3.35
# 2       mahebourg -20.41   57.70     25.00        78          40        5.70
# 4           bluff -46.60  168.33     12.78        97          99        2.24
# 5         kavieng  -2.57  150.80     28.02        77          36        5.34
# 7           kindu  -2.95   25.95     21.20        95         100        0.87
# ...           ...    ...     ...       ...       ...         ...         ...
# 1128       labrea  -7.26  -64.80     88.95        59          90        2.75
# 1130      waitati -45.75  170.57     55.00        95         100       11.01
# 1131      sunbury -37.58  144.73     66.74        68           0       12.75
# 1141  warrnambool -38.38  142.48     60.48        90         100        7.09
# 1142        otane -39.88  176.63     71.01        66          91        2.04
#
#      Country        Date
# 1         AR  1609519501
# 2         MU  1609519501
# 4         NZ  1609519501
# 5         PG  1609519501
# 7         CD  1609519504
# ...      ...         ...
# 1128      BR  1609532684
# 1130      NZ  1609532684
# 1131      AU  1609532684
# 1141      AU  1609532685
# 1142      NZ  1609532685
#
# [269 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values=northern_hemisphere_data['Lat']
y_values=northern_hemisphere_data['Max Temp']
plot_linear_regression(x_values,y_values,'Max Temp',(40,60))
# Out:
# The r-value is: 0.468567335978852

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values=southern_hemisphere_data['Lat']
y_values=southern_hemisphere_data['Max Temp']
plot_linear_regression(x_values,y_values,'Max Temp',(-40,45))
# Out:
# The r-value is: 0.019669896960740507

# %% [markdown]
# * Based on r-values there is moderate uphill relationship between latitude and max temperature in the Northern hemisphere and no relationship between latitude and max temperature in the Southern hemisphere based on the temperature from 1/1/21.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values=northern_hemisphere_data['Lat']
y_values=northern_hemisphere_data['Humidity']
plot_linear_regression(x_values,y_values,'Humidity',(40,40))
# Out:
# The r-value is: 0.1968007681551106

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values=southern_hemisphere_data['Lat']
y_values=southern_hemisphere_data['Humidity']
plot_linear_regression(x_values,y_values,'Humidity',(-40,25))
# Out:
# The r-value is: 0.047137633186790796

# %% [markdown]
# * Based on r-values there is low uphill relationship between latitude and humidity in the Northern hemisphere and no relationship between latitude and humidity in the Southern hemisphere based on the data from 1/1/21.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values=northern_hemisphere_data['Lat']
y_values=northern_hemisphere_data['Cloudiness']
plot_linear_regression(x_values,y_values,'Cloudiness',(40,30))
# Out:
# The r-value is: 0.056194201508531556

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values=southern_hemisphere_data['Lat']
y_values=southern_hemisphere_data['Cloudiness']
plot_linear_regression(x_values,y_values,'Cloudiness',(-40,30))
# Out:
# The r-value is: 0.04416856040057562

# %% [markdown]
# * Based on r-values there is no relationship between latitude and cloudiness in both Northern and Southern hemispheres based on the data from 1/1/21.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values=northern_hemisphere_data['Lat']
y_values=northern_hemisphere_data['Wind Speed']
plot_linear_regression(x_values,y_values,'Wind Speed',(40,20))
# Out:
# The r-value is: 0.007567651986672524

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values=southern_hemisphere_data['Lat']
y_values=southern_hemisphere_data['Wind Speed']
plot_linear_regression(x_values,y_values,'Wind Speed',(-40,8))
# Out:
# The r-value is: 0.012998307985129303

# %% [markdown]
# * Based on r-values there is no relationship between latitude and wind speed in both Northern and Southern hemispheres based on the data from 1/1/21.
